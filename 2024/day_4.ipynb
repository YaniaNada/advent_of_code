# %% [markdown]
# <a href="https://colab.research.google.com/github/YaniaNada/advent_of_code/blob/main/day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Work in progress...

# %%
'Day 4 challenge: https://adventofcode.com/2024/day/4'
# Out:
# 'Day 4 challenge: https://adventofcode.com/2024/day/4'

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
year = 2024
day = 4  # Change to the day you want
session_cookie = "53616c7465645f5f82db0407cfb5bf0059b99d2e334bbf4e0e58a4783c7cf8a133fec5d4cf1163adcbc9d6416594a0b4514cd31e99ab547813e9f599d40e3ffd"

url = f"https://adventofcode.com/{year}/day/{day}/input"
cookies = {"session": session_cookie}

response = requests.get(url, cookies=cookies)

if response.ok:
    puzzle_input = response.text.strip()
    print(puzzle_input)
else:
    print("Failed to fetch input:", response.status_code)
# Out:
# SMXMMAXXXXMMMMSMMASASMSXMMAMSSMXSMMXMASAMXXMAMXAXXAMXAXASMSMSMMMSXXSXSXXAAMXXSXMASMAASXMXMSSMXXXXMMSSSMXSXXMASXMMSMSXMXSSMXSMMMSXMSAMSASXSAM
# MASMMSXMMMMAMSMAXSAMXAXAXXAXSASAMASMMASAMAXMAXMMSXASMMMMSAAXAAAAXSMAAAAMAMXSSMMXMASMSAMXSAAAMSMMMSMAAAMMMXMXAXASAASXASAXMASMAAXXAXMAMXXSSMAM
# MAMAAMXMAXSASAMMMXAMMMMAMMSMSAMXSAMXMASAMMSXSASAMXSMAAAMMXMMSMMXMAMSSMMAAMAMAXAAXMAMXAMSAMMSMAXAAAMMSMMAAXSMMSXMSMMSAMXSXMXXMMSSMMMSMMXMASXM
# MAMMMXAMXMXXSASXAXAMSXMXSAAXMMMXMXSXMXSMMXMAXAMXXXXXSSSSXAMXXAMMAMXAXAXSAMMSMMMSMMSMSAMAAXMAMXSMSXXAXMSSSSMAXSAMXMMMSXAXAXAMMXMASXAMAMSXAMMX
# SSSXXSMMSMMXSAAMSSSMMXSAMMSMMMMMMASASAMASMMMMXSSSSMXMAMMMXSASAMXXXSXMMMMASXAXASAMMAAMXMSMMSMXMXXAMXXSMAMMXMAMMXAAXMAMMSSMMXXAASAMMXSAMAMSSMM
# AAXMASMAAASAMXMAMMAAXXMASAXXMAAAXMSAMXSAMAMXSAAAAXAAMAMAAXAMMMMSMAXMXSASAMMMMMAASMMSMAMAXXXMASAMXSAAMXAXMASXMSASMSMMMMMAXAAXSXMASAMSAMMXMAMA
# ...

# %%
lines = puzzle_input.split('\n')
print(len(puzzle_input))
print(len(lines))
# Out:
# 19739
# 140

# %%
print(lines[0], 'length: ', len(lines[0]))
print(lines[10], 'length: ', len(lines[10]))
print(lines[50], 'length: ', len(lines[50]))
print(lines[139], 'length: ', len(lines[139]))
# Out:
# SMXMMAXXXXMMMMSMMASASMSXMMAMSSMXSMMXMASAMXXMAMXAXXAMXAXASMSMSMMMSXXSXSXXAAMXXSXMASMAASXMXMSSMXXXXMMSSSMXSXXMASXMMSMSXMXSSMXSMMMSXMSAMSASXSAM length:  140
# MMAMMMSMSSMMAAMASMMXMASAAASASMAASAMSMXMXAXSAMASMMXSAMAMXAMXXMAMXSAMAXMAMAASAMASAMAMXAASMMMAXXMXMASMXMASMXSAMAXXXXAAAMAMAMXMAMAAMXMAMXMXMMMMS length:  140
# MMASXMAXAMMSAMAMASXMASAXAMSMSSSSSSMAXAAASMMSAMXXMAMAXSAXAXXXAAAXSXMAMAMSASASXSXSAMXSAAAXAAMAMMMAXAAMXSMAMXMAMXMAMXASAAAXMXASXXSMSASMSAAMMMAS length:  140
# MSMMSXXXAXXSAMXXSASXMXSMXMSMSMMMMMASXSMXSMMSMSMMMAMXMXMSSSXSXMMMSMMMMXXXSAMXXMXMSMSMMSXMAMMXMASAXMMXMASXSSMMMXSXSMXSMSXMXMMMSMXSXMSMSXMSAMAM length:  140

# %%
'''sample = ["MMMSXXMASM",
"MSAMXMSMSA",
"AMXSXMAAMM",
"MSAMASMSMX",
"XMASAMXAMM",
"XXAMMXXAMA",
"SMSMSASXSS",
"SAXAMASAAA",
"MAMMMXMMMM",
"MXMXAXMASX"]

lines = sample

print(len(puzzle_input[1]), puzzle_input[1])
print(len(puzzle_input[9]), puzzle_input[9])'''
# Out:
# 'sample = ["MMMSXXMASM",\n"MSAMXMSMSA",\n"AMXSXMAAMM",\n"MSAMASMSMX",\n"XMASAMXAMM",\n"XXAMMXXAMA",\n"SMSMSASXSS",\n"SAXAMASAAA",\n"MAMMMXMMMM",\n"MXMXAXMASX"]\n\nlines = sample\n\nprint(len(puzzle_input[1]), puzzle_input[1])\nprint(len(puzzle_input[9]), puzzle_input[9])'

# %%
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('X'):
      '''print('i: ',i)
      print('j: ',j)
      print(lines[i][j])'''

# Output
'''
i:  139 -> line number
j:  133 -> character position in line
X -> character value in position j in line i

i:  56 -> line number
j:  65 -> character position in line
X -> In line 56th, character 65th is an X
'''
# Out:
# '\ni:  139 -> line number\nj:  133 -> character position in line\nX -> character value in position j in line i\n\ni:  56 -> line number\nj:  65 -> character position in line\nX -> In line 56th, character 65th is an X\n'

# %% [markdown]
# # Horizontal XMAS or SAMX

# %%
count_xmas_hrz = 0
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('X'):
      if (0 <= i < len(lines)) and (0 <= j < len(lines[i])-3):
        index_1 = j +1
        index_2 = j +2
        index_3 = j +3
        if lines[i][index_1] == 'M':
          if lines[i][index_2] == 'A':
            if lines[i][index_3] == 'S':
              '''print('Found XMAS')
              print(i, j, index_1, index_2, index_3)
              print(lines[i][j],lines[i][index_1],lines[i][index_2],lines[i][index_3])'''
              count_xmas_hrz +=1

for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('S'):
      if (0 <= i < len(lines)) and (0 <= j < len(lines[i])-3):
        index_1 = j +1
        index_2 = j +2
        index_3 = j +3
        if lines[i][index_1] == 'A':
          if lines[i][index_2] == 'M':
            if lines[i][index_3] == 'X':
              '''print('Found XMAS')
              print(i, j, index_1, index_2, index_3)
              print(lines[i][j],lines[i][index_1],lines[i][index_2],lines[i][index_3])'''
              count_xmas_hrz +=1

print('horizontal XMAS or SAMX: ', count_xmas_hrz)
# Out:
# horizontal XMAS or SAMX:  400

# %% [markdown]
# # Diagonal XMAS:

# %%
count_xmas_fd_1 = 0
count_xmas_fd_2 = 0
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('X'):
      if i < len(lines)-3 and j < len(lines[i])-3:
        index_1 = j +1
        index_2 = j +2
        index_3 = j +3
        if lines[i+1][index_1] == 'M':
          if lines[i+2][index_2] == 'A':
            if lines[i+3][index_3] == 'S':
              '''print('Found XMAS')
              print(i, j, index_1, index_2, index_3)
              print(lines[i][j],lines[i+1][index_1],lines[i+2][index_2],lines[i+3][index_3])'''
              count_xmas_fd_1 +=1

      if i < len(lines)-3 and (3 <= j < len(lines[i])):
        index_1 = j -1
        index_2 = j -2
        index_3 = j -3
        if lines[i+1][index_1] == 'M':
          if lines[i+2][index_2] == 'A':
            if lines[i+3][index_3] == 'S':
              '''print('Found XMAS')
              print(i, j, index_1, index_2, index_3)
              print(lines[i][j],lines[i+1][index_1],lines[i+2][index_2],lines[i+3][index_3])'''
              count_xmas_fd_2 +=1

print('Diagonal XMAS, forward & backward: ', count_xmas_fd_1, count_xmas_fd_2)
# Out:
# Diagonal XMAS, forward & backward:  420 401

# %% [markdown]
# # Diagonal SAMX

# %%
count_xmas_bd_1 = 0
count_xmas_bd_2 = 0
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('S'):
      if i < len(lines)-3 and j < len(lines[i])-3:
        index_1 = j +1
        index_2 = j +2
        index_3 = j +3
        if lines[i+1][index_1] == 'A':
          if lines[i+2][index_2] == 'M':
            if lines[i+3][index_3] == 'X':
              '''print('Found XMAS')
              print(i, j, index_1, index_2, index_3)
              print(lines[i][j],lines[i+1][index_1],lines[i+2][index_2],lines[i+3][index_3])'''
              count_xmas_bd_1 +=1

for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('S'):
      if i < len(lines)-3 and (3 <= j < len(lines[i])):
        index_1 = j -1
        index_2 = j -2
        index_3 = j -3
        if lines[i+1][index_1] == 'A':
          if lines[i+2][index_2] == 'M':
            if lines[i+3][index_3] == 'X':
              '''print('Found XMAS')
              print(i, j, index_1, index_2, index_3)
              print(lines[i][j],lines[i+1][index_1],lines[i+2][index_2],lines[i+3][index_3])'''
              count_xmas_bd_2 +=1

print('Diagonal SAMX, forward and backward: ', count_xmas_bd_1, count_xmas_bd_2)
# Out:
# Diagonal SAMX, forward and backward:  426 442

# %% [markdown]
# # Vertical XMAS OR SAMX

# %%
count_xmas_vrt = 0
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('X'):
      if i < len(lines)-3 and j < len(lines[i]):
        if lines[i+1][j] == 'M':
          if lines[i+2][j] == 'A':
            if lines[i+3][j] == 'S':
              '''print('Found XMAS')
              print(i, j)
              print(lines[i][j],lines[i+1][j],lines[i+2][j],lines[i+3][j])'''
              count_xmas_vrt +=1

for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('S'):
      if i < len(lines)-3 and j < len(lines[i]):
        if lines[i+1][j] == 'A':
          if lines[i+2][j] == 'M':
            if lines[i+3][j] == 'X':
              '''print('Found XMAS')
              print(i, j)
              print(lines[i][j],lines[i+1][j],lines[i+2][j],lines[i+3][j])'''
              count_xmas_vrt +=1

print('vertical XMAS or SAMX: ', count_xmas_vrt)
# Out:
# vertical XMAS or SAMX:  454

# %%
xmas_count = count_xmas_hrz+count_xmas_vrt+count_xmas_fd_1+count_xmas_fd_2+count_xmas_bd_1+count_xmas_bd_2
print(f'Total XMAS: {xmas_count}')
# Out:
# Total XMAS: 2543

# %% [markdown]
# # Part II

# %%
"""sample = [".M.S......",
          "..A..MSMS.",
          ".M.S.MAA..",
          "..A.ASMSM.",
          ".M.S.M....",
          "..........",
          "S.S.S.S.S.",
          ".A.A.A.A..",
          "M.M.M.M.M.",
          ".........."]
    lines = sample
          """

# Find X: SAM & MAS
count_MAS_1 = 0
for i in range(len(lines)):
    for j in range(len(lines[i])):
        if lines[i][j] == 'S':
            if i < len(lines)-2 and j < len(lines[i])-2:
                if lines[i][j+2] == 'M':
                    if lines[i+1][j+1] == 'A':
                        if lines[i+2][j] == 'S':
                            if lines[i+2][j+2] == 'M':
                                count_MAS_1 = count_MAS_1+1
                                """print(f"i: {i}, j: {j}")
                                print(f"MAS_1: {count_MAS_1}")"""

# Find X: MAS & SAM
count_MAS_2 = 0
for i in range(len(lines)):
    for j in range(len(lines[i])):
        if lines[i][j] == 'M':
            if i < len(lines)-2 and j < len(lines[i])-2:
                if lines[i][j+2] == 'S':
                    if lines[i+1][j+1] == 'A':
                        if lines[i+2][j] == 'M':
                            if lines[i+2][j+2] == 'S':
                                count_MAS_2 = count_MAS_2+1
                                """print(f"i: {i}, j: {j}")
                                print(f"MAS_2: {count_MAS_2}")"""

# Find X: MAS & MAS
count_MAS_3 = 0
for i in range(len(lines)):
    for j in range(len(lines[i])):
        if lines[i][j] == 'M':
            if i < len(lines)-2 and j < len(lines[i])-2:
                if lines[i][j+2] == 'M':
                    if lines[i+1][j+1] == 'A':
                        if lines[i+2][j] == 'S':
                            if lines[i+2][j+2] == 'S':
                                count_MAS_3 = count_MAS_3+1
                                """print(f"i: {i}, j: {j}")
                                print(f"MAS_2: {count_MAS_3}")"""

# Find X: SAM & SAM
count_MAS_4 = 0
for i in range(len(lines)):
    for j in range(len(lines[i])):
        if lines[i][j] == 'S':
            if i < len(lines)-2 and j < len(lines[i])-2:
                if lines[i][j+2] == 'S':
                    if lines[i+1][j+1] == 'A':
                        if lines[i+2][j] == 'M':
                            if lines[i+2][j+2] == 'M':
                                count_MAS_4 = count_MAS_4+1
                                """print(f"i: {i}, j: {j}")
                                print(f"MAS_2: {count_MAS_4}")"""

print('Total MAS: ', count_MAS_1+count_MAS_2+count_MAS_3+count_MAS_4)
# Out:
# Total MAS:  1930
