# %% [markdown]
# <a href="https://colab.research.google.com/github/YaniaNada/advent_of_code/blob/main/day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Work in progress...

# %%
'Day 4 challenge: https://adventofcode.com/2024/day/4'
# Out:
# 'Day 4 challenge: https://adventofcode.com/2024/day/4'

# %%
import pandas as pd

# %%
import re

# %%
import requests
from bs4 import BeautifulSoup

# %%
year = 2024
day = 4  # Change to the day you want
session_cookie = "53616c7465645f5fe0a9be52b687b2d723bd1e1676347871a5375696baf7d8a2f3321167b6fc4c920c47444809bda0a3b9ddcc460a69075a02af1ff6454ba208"

url = f"https://adventofcode.com/{year}/day/{day}/input"
cookies = {"session": session_cookie}

response = requests.get(url, cookies=cookies)

if response.ok:
    puzzle_input = response.text.strip()
    print(puzzle_input)
else:
    print("Failed to fetch input:", response.status_code)
# Out:
# SMXMMAXXXXMMMMSMMASASMSXMMAMSSMXSMMXMASAMXXMAMXAXXAMXAXASMSMSMMMSXXSXSXXAAMXXSXMASMAASXMXMSSMXXXXMMSSSMXSXXMASXMMSMSXMXSSMXSMMMSXMSAMSASXSAM
# MASMMSXMMMMAMSMAXSAMXAXAXXAXSASAMASMMASAMAXMAXMMSXASMMMMSAAXAAAAXSMAAAAMAMXSSMMXMASMSAMXSAAAMSMMMSMAAAMMMXMXAXASAASXASAXMASMAAXXAXMAMXXSSMAM
# MAMAAMXMAXSASAMMMXAMMMMAMMSMSAMXSAMXMASAMMSXSASAMXSMAAAMMXMMSMMXMAMSSMMAAMAMAXAAXMAMXAMSAMMSMAXAAAMMSMMAAXSMMSXMSMMSAMXSXMXXMMSSMMMSMMXMASXM
# MAMMMXAMXMXXSASXAXAMSXMXSAAXMMMXMXSXMXSMMXMAXAMXXXXXSSSSXAMXXAMMAMXAXAXSAMMSMMMSMMSMSAMAAXMAMXSMSXXAXMSSSSMAXSAMXMMMSXAXAXAMMXMASXAMAMSXAMMX
# SSSXXSMMSMMXSAAMSSSMMXSAMMSMMMMMMASASAMASMMMMXSSSSMXMAMMMXSASAMXXXSXMMMMASXAXASAMMAAMXMSMMSMXMXXAMXXSMAMMXMAMMXAAXMAMMSSMMXXAASAMMXSAMAMSSMM
# AAXMASMAAASAMXMAMMAAXXMASAXXMAAAXMSAMXSAMAMXSAAAAXAAMAMAAXAMMMMSMAXMXSASAMMMMMAASMMSMAMAXXXMASAMXSAAMXAXMASXMSASMSMMMMMAXAAXSXMASAMSAMMXMAMA
# ...

# %%
lines = puzzle_input.split('\n')
print(len(puzzle_input))
print(len(lines))
# Out:
# 19739
# 140

# %%
print(lines[0], 'length: ', len(lines[0]))
print(lines[10], 'length: ', len(lines[10]))
print(lines[50], 'length: ', len(lines[50]))
print(lines[139], 'length: ', len(lines[139]))
# Out:
# SMXMMAXXXXMMMMSMMASASMSXMMAMSSMXSMMXMASAMXXMAMXAXXAMXAXASMSMSMMMSXXSXSXXAAMXXSXMASMAASXMXMSSMXXXXMMSSSMXSXXMASXMMSMSXMXSSMXSMMMSXMSAMSASXSAM length:  140
# MMAMMMSMSSMMAAMASMMXMASAAASASMAASAMSMXMXAXSAMASMMXSAMAMXAMXXMAMXSAMAXMAMAASAMASAMAMXAASMMMAXXMXMASMXMASMXSAMAXXXXAAAMAMAMXMAMAAMXMAMXMXMMMMS length:  140
# MMASXMAXAMMSAMAMASXMASAXAMSMSSSSSSMAXAAASMMSAMXXMAMAXSAXAXXXAAAXSXMAMAMSASASXSXSAMXSAAAXAAMAMMMAXAAMXSMAMXMAMXMAMXASAAAXMXASXXSMSASMSAAMMMAS length:  140
# MSMMSXXXAXXSAMXXSASXMXSMXMSMSMMMMMASXSMXSMMSMSMMMAMXMXMSSSXSXMMMSMMMMXXXSAMXXMXMSMSMMSXMAMMXMASAXMMXMASXSSMMMXSXSMXSMSXMXMMMSMXSXMSMSXMSAMAM length:  140

# %% [markdown]
# # Horizontal XMAS:

# %%
match = re.findall(r'XMAS|SAMX', puzzle_input)
print('Total horizontal XMAS: ', len(match))
# Out:
# Total horizontal XMAS:  379

# %% [markdown]
# # Forward Diagonal XMAS:

# %%
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('X'):
      print('i: ',i)
      print('j: ',j)
      print(lines[i][j])

# Output
'''
i:  139 -> line number
j:  133 -> character position in line
X -> character value in position j in line i

i:  56 -> line number
j:  65 -> character position in line
X -> In line 56th, character 65th is an X
'''
# Out:
# i:  0
# j:  2
# X
# i:  0
# j:  6
# X
# i:  0
# j:  7
# X
# i:  0
# j:  8
# X
# i:  0
# j:  9
# X
# i:  0
# j:  23
# X
# i:  0
# j:  31
# X
# i:  0
# j:  35
# X
# i:  0
# j:  41
# X
# i:  0
# j:  42
# X
# i:  0
# j:  46
# X
# i:  0
# j:  48
# X
# i:  0
# j:  49
# X
# i:  0
# j:  52
# X
# i:  0
# j:  54
# X
# i:  0
# j:  65
# X
# i:  0
# j:  66
# X
# i:  0
# j:  68
# X
# i:  0
# j:  70
# X
# i:  0
# j:  71
# X
# i:  0
# j:  75
# X
# i:  0
# j:  76
# X
# i:  0
# j:  78
# X
# i:  0
# j:  86
# X
# i:  0
# j:  88
# X
# i:  0
# j:  93
# X
# i:  0
# j:  94
# X
# i:  0
# j:  95
# X
# i:  0
# j:  96
# X
# i:  0
# j:  103
# X
# i:  0
# j:  105
# X
# i:  0
# j:  106
# X
# i:  0
# j:  110
# X
# i:  0
# j:  116
# X
# i:  0
# j:  118
# X
# i:  0
# j:  122
# X
# i:  0
# j:  128
# X
# i:  0
# j:  136
# X
# i:  1
# j:  6
# X
# i:  1
# j:  16
# X
# i:  1
# j:  20
# X
# i:  1
# j:  22
# X
# i:  1
# j:  24
# X
# i:  1
# j:  25
# X
# i:  1
# j:  27
# X
# i:  1
# j:  42
# X
# i:  1
# j:  45
# X
# i:  1
# ...

# %%
count_xmas = 0
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('X'):
      if i < len(lines)-3 and j < len(lines[i])-3:
        m_index = j +1
        a_index = j +2
        s_index = j +3
        if lines[i+1][m_index] == 'M':
          if lines[i+2][a_index] == 'A':
            if lines[i+3][s_index] == 'S':
              '''print('Found XMAS')
              print(i, j, m_index, a_index, s_index)
              print(lines[i][j],lines[i+1][m_index],lines[i+2][a_index],lines[i+3][s_index])'''
              count_xmas +=1

      if i < len(lines)-3 and j < len(lines[i])-3:
        m_index = j -1
        a_index = j -2
        s_index = j -3
        if lines[i+1][m_index] == 'M':
          if lines[i+2][a_index] == 'A':
            if lines[i+3][s_index] == 'S':
              '''print('Found XMAS')
              print(i, j, m_index, a_index, s_index)
              print(lines[i][j],lines[i+1][m_index],lines[i+2][a_index],lines[i+3][s_index])'''
              count_xmas +=1

print(count_xmas)

# output
'''
Found XMAS
136 107 108 109 110
X M A S
Found XMAS
136 107 106 105 104
X M A S
'''
# Out:
# 815
# '\nFound XMAS\n136 107 108 109 110\nX M A S\nFound XMAS\n136 107 106 105 104\nX M A S\n'

# %%
count_xmas = 0
for i in range(len(lines)):
  for j in range(len(lines[i])):
    if lines[i][j] == ('S'):
      if i < len(lines)-3 and j < len(lines[i])-3:
        m_index = j +1
        a_index = j +2
        s_index = j +3
        if lines[i+1][m_index] == 'A':
          if lines[i+2][a_index] == 'M':
            if lines[i+3][s_index] == 'X':
              '''print('Found XMAS')
              print(i, j, m_index, a_index, s_index)
              print(lines[i][j],lines[i+1][m_index],lines[i+2][a_index],lines[i+3][s_index])'''
              count_xmas +=1

      if i < len(lines)-3 and j < len(lines[i])-3:
        m_index = j -1
        a_index = j -2
        s_index = j -3
        if lines[i+1][m_index] == 'A':
          if lines[i+2][a_index] == 'M':
            if lines[i+3][s_index] == 'X':
              '''print('Found XMAS')
              print(i, j, m_index, a_index, s_index)
              print(lines[i][j],lines[i+1][m_index],lines[i+2][a_index],lines[i+3][s_index])'''
              count_xmas +=1

print(count_xmas)


# OUTPUT
'''
Found XMAS
132 108 109 110 111
S A M X
Found XMAS
132 114 113 112 111
S A M X
'''
# Out:
# Found XMAS
# 0 14 15 16 17
# S A M X
# Found XMAS
# 0 20 21 22 23
# S A M X
# Found XMAS
# 0 28 29 30 31
# S A M X
# Found XMAS
# 0 32 33 34 35
# S A M X
# Found XMAS
# 0 38 39 40 41
# S A M X
# Found XMAS
# 0 38 37 36 35
# S A M X
# Found XMAS
# 0 56 57 58 59
# S A M X
# Found XMAS
# 0 67 68 69 70
# S A M X
# Found XMAS
# 0 90 91 92 93
# S A M X
# Found XMAS
# 0 100 99 98 97
# S A M X
# Found XMAS
# 0 101 100 99 98
# S A M X
# Found XMAS
# 0 109 110 111 112
# S A M X
# Found XMAS
# 1 48 47 46 45
# S A M X
# Found XMAS
# 1 97 96 95 94
# S A M X
# Found XMAS
# 2 46 45 44 43
# S A M X
# Found XMAS
# 2 87 88 89 90
# S A M X
# Found XMAS
# 3 14 13 12 11
# S A M X
# Found XMAS
# 3 34 35 36 37
# S A M X
# Found XMAS
# 3 38 37 36 35
# S A M X
# Found XMAS
# 3 54 53 52 51
# S A M X
# Found XMAS
# 3 71 72 73 74
# S A M X
# Found XMAS
# 4 0 -1 -2 -3
# S A M X
# Found XMAS
# 4 5 4 3 2
# S A M X
# Found XMAS
# 4 8 9 10 11
# S A M X
# Found XMAS
# 4 34 35 36 37
# S A M X
# Found XMAS
# ...
